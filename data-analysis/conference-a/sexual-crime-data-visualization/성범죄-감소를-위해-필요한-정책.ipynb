# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
# %matplotlib inline
import platform

from matplotlib import font_manager, rc 
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system')

# %%
df = pd.read_csv('C:\\Users\\Owner\\Downloads\\성폭력을_감소시키기_위해_요구되는_정책_20200901091855.csv', encoding='utf-8')
df
# Out:
#     반 성폭력 정책(1)                             반 성폭력 정책(2)    2019 2019.1 2019.2  \
# 0   반 성폭력 정책(1)                             반 성폭력 정책(2)      전체     전체     전체
# 1   반 성폭력 정책(1)                             반 성폭력 정책(2)  평균 (점)   표준편차   평균순위
# 2          범죄예방       TV 공익광고 SNS 등을 활용한 성폭력방지 캠페인 및 홍보     6.1      1     12
# 3          범죄예방  안전한 생활환경 조성(방범용 CCTV 설치 안전벨 설치 방범활동 등)     6.3    0.8      3
# 4          범죄예방                   가해자 교정 치료를 통한 재범방지 강화     6.3    0.9      4
# 5      수사기관의 개선                  범죄 발생 시 신속한 수사와 가해자 검거     6.4    0.8      2
# 6      수사기관의 개선                       수사기관의 성 인지 감수성 강화     6.1    0.9     11
# 7      수사기관의 개선                  수사기관 내 성폭력 전문 전담인력의 확충     6.2    0.9      9
# 8      처벌 수준 강화                               가해자 처벌 강화     6.4    0.8      1
# 9      처벌 수준 강화        불법촬영물 및 유포에 한정되어 있는 처벌 대상 범위의 확대     6.3    0.9      5
# 10       피해자 보호                           피해자 지원 서비스 확대     6.2    0.9      8
# ...

# %%
df = df.drop(['2019.1', '2019.2','2019.3','2019.4','2019.5','2019.6','2019.7','2019.8',], axis=1)
df
# Out:
#     반 성폭력 정책(1)                             반 성폭력 정책(2)    2019
# 0   반 성폭력 정책(1)                             반 성폭력 정책(2)      전체
# 1   반 성폭력 정책(1)                             반 성폭력 정책(2)  평균 (점)
# 2          범죄예방       TV 공익광고 SNS 등을 활용한 성폭력방지 캠페인 및 홍보     6.1
# 3          범죄예방  안전한 생활환경 조성(방범용 CCTV 설치 안전벨 설치 방범활동 등)     6.3
# 4          범죄예방                   가해자 교정 치료를 통한 재범방지 강화     6.3
# 5      수사기관의 개선                  범죄 발생 시 신속한 수사와 가해자 검거     6.4
# 6      수사기관의 개선                       수사기관의 성 인지 감수성 강화     6.1
# 7      수사기관의 개선                  수사기관 내 성폭력 전문 전담인력의 확충     6.2
# 8      처벌 수준 강화                               가해자 처벌 강화     6.4
# 9      처벌 수준 강화        불법촬영물 및 유포에 한정되어 있는 처벌 대상 범위의 확대     6.3
# 10       피해자 보호                           피해자 지원 서비스 확대     6.2
# 11       피해자 보호                 피해자의 2차 피해 방지를 위한 정책 마련     6.2
# 12    사회적 인식 개선               피해자 인권 보호에 대한 전사회적인 인식 개선     6.2
# 13    사회적 인식 개선               시민 대상 성 인권 및 폭력 감수성 교육 확대     6.1

# %%
df = df.set_index('반 성폭력 정책(1)')
df = df.drop('반 성폭력 정책(1)')
df
# Out:
#                                         반 성폭력 정책(2) 2019
# 반 성폭력 정책(1)
# 범죄예방              TV 공익광고 SNS 등을 활용한 성폭력방지 캠페인 및 홍보  6.1
# 범죄예방         안전한 생활환경 조성(방범용 CCTV 설치 안전벨 설치 방범활동 등)  6.3
# 범죄예방                          가해자 교정 치료를 통한 재범방지 강화  6.3
# 수사기관의 개선                     범죄 발생 시 신속한 수사와 가해자 검거  6.4
# 수사기관의 개선                          수사기관의 성 인지 감수성 강화  6.1
# 수사기관의 개선                     수사기관 내 성폭력 전문 전담인력의 확충  6.2
# 처벌 수준 강화                                  가해자 처벌 강화  6.4
# 처벌 수준 강화           불법촬영물 및 유포에 한정되어 있는 처벌 대상 범위의 확대  6.3
# 피해자 보호                                피해자 지원 서비스 확대  6.2
# 피해자 보호                      피해자의 2차 피해 방지를 위한 정책 마련  6.2
# 사회적 인식 개선                 피해자 인권 보호에 대한 전사회적인 인식 개선  6.2
# 사회적 인식 개선                 시민 대상 성 인권 및 폭력 감수성 교육 확대  6.1

# %%
plt.xticks(rotation = 45)
plt.rcParams['figure.figsize'] = [7,5]

sns.barplot(x = '2019', y='반 성폭력 정책(2)', data =df)
title = '성범죄-감소를-위해-필요한-정책'
plt.title(title)
plt.savefig(title+'.png')

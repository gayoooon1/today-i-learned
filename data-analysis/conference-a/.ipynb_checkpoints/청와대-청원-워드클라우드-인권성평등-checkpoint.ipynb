# %% [markdown]
# ### 작성자 : 김가윤

# %% [markdown]
# ### 데이터 모으기
# 본 데이터프레임은 청원시작일 기준 17.8 ~ 20.8의 청원 목록을 담고 있으며, 참여인원이 10000명이 넘는 목록만 수집했음을 밝힙니다.

# %%
import pandas as pd

df_old = pd.read_csv('C:\\Users\\Owner\\Documents\\카카오톡 받은 파일\\final-blue-house-petition-best.csv', index_col = 0)

# %%
import re 
import time
from tqdm import tqdm_notebook # PYTHON 진행표시바 만들기
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

# %%
pet_title = []
pet_start = []
pet_end = []
pet_ppl = []
pet_url = []
category = []

content = []



#def get_data() :
for pgn in range(1,6):
    urlbd = 'https://www1.president.go.kr/petitions/best?page='
    pg = urlopen(urlbd + str(pgn))
    soup = BeautifulSoup(pg, "html.parser")

    titles = soup.select('.b_list.category > .bl_body li .bl_wrap > .bl_subject > a.cb')
    urls = soup.select('.b_list.category > .bl_body li .bl_wrap > .bl_subject > a')           
    
    for title in titles:
        pet_title.append(title.get_text()[3:])
    
    for url in urls:
        pet_url.append('https://www1.president.go.kr' + url['href'])
     
data = {'제목':pet_title, 'URL':pet_url}
df = pd.DataFrame(data)


for n in tqdm_notebook(df.index): 
    url = urlopen(df['URL'][n]) 
    time.sleep(1)
    soup = BeautifulSoup(url, "html.parser")
    tmp = soup.select('h2.petitionsView_count > span.counter')
    for t in tmp:
        x = t.get_text()
        pet_ppl.append(x)
    tmp_x = soup.find('ul',class_='petitionsView_info_list').get_text()
    p0 = re.compile('\s')
    splited = p0.split(tmp_x) #tmp_y.li.get_text()
    category.append(splited[1:5][0][4:])
    pet_start.append(splited[1:5][1][4:])
    pet_end.append(splited[1:5][2][4:])
    tmp_y = soup.find_all('div',class_='View_write')
    if len(tmp_y) > 1:
        content_raw = tmp_y[1].get_text()
    else:
        content_raw = tmp_y[0].get_text()
    p1 = re.compile('\r|\t|\n|\xa0')
    content_splited = p1.split(content_raw)
    content.append(''.join(content_splited)) # 청원내용 가져오기
    
df['카테고리'] = category
df['청원내용'] = content
df['청원시작일'] = pet_start
df['청원종료일'] = pet_end
df['참여인원'] = pet_ppl


df.head()
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:31: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=145.0), HTML(value='')))
#                                                 제목  \
# 0               응급환자가 있는 구급차를 막아세운 택시 기사를 처벌해 주세요.
# 1            강영수 서울고법 수석부장판사의 대법관 후보 자격 박탈을 청원합니다.
# 2                   정부의 교회 정규 예배 이외 행사 금지를 취소해주세요.
# 3            박원순씨 장례를 5일장, 서울특별시장(葬)으로 하는 것 반대합니다.
# 4   학교내성폭력 및 학교.상급기관의 미흡한 대처로 아픔을 호소하다 하늘나라에 갔습니다.
#
#                                              URL    카테고리  \
# 0  https://www1.president.go.kr/petitions/590341   안전/환경
# 1  https://www1.president.go.kr/petitions/590416  인권/성평등
# 2  https://www1.president.go.kr/petitions/590504      행정
# 3  https://www1.president.go.kr/petitions/590550  인권/성평등
# 4  https://www1.president.go.kr/petitions/590879  인권/성평등
#
#                                                 청원내용       청원시작일       청원종료일  \
# 0  2020년 6월 8일 월요일 오후 3시 15분오후 3시 15분경 어머님의 호흡이 너...  2020-07-03  2020-08-02
# 1  현재 대법관 후보에 올라있는 강영수 판사는 현재 세계 최대의 아동 성착취물 사이트인...  2020-07-06  2020-08-05
# 2  7월 8일, 중앙재난안전대책본부 "교회의 책임자와 이용자는 7월 10일(금) 18시...  2020-07-08  2020-08-07
# 3  박원순씨가 사망하는 바람에 성추행 의혹은 수사도 하지 못한 채 종결되었지만그렇다고 ...  2020-07-10  2020-08-09
# 4  6월 19일 첫 신고 시 학교측은 성폭력 매뉴얼대로 진행하지 않고 사건을 축소하여 ...  2020-07-16  2020-08-15
#
#       참여인원
# 0  735,972
# 1  529,144
# 2  427,470
# 3  596,410
# 4  252,624

# %%
#df['참여인원'] = df['참여인원'].str.replace(',','')
#df['참여인원'] = df['참여인원'].apply(pd.to_numeric)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제목      145 non-null    object
#  1   URL     145 non-null    object
#  2   카테고리    145 non-null    object
#  3   청원내용    145 non-null    object
#  4   청원시작일   145 non-null    object
#  5   청원종료일   145 non-null    object
#  6   참여인원    145 non-null    int64
# dtypes: int64(1), object(6)
# memory usage: 8.1+ KB

# %%
petition_best = pd.concat([df, df_old])
petition_best
# Out:
#                                                      제목  \
# 0                    응급환자가 있는 구급차를 막아세운 택시 기사를 처벌해 주세요.
# 1                 강영수 서울고법 수석부장판사의 대법관 후보 자격 박탈을 청원합니다.
# 2                        정부의 교회 정규 예배 이외 행사 금지를 취소해주세요.
# 3                 박원순씨 장례를 5일장, 서울특별시장(葬)으로 하는 것 반대합니다.
# 4        학교내성폭력 및 학교.상급기관의 미흡한 대처로 아픔을 호소하다 하늘나라에 갔습니다.
# ...                                                 ...
# 1535  **의 구** 씨의 원래 교제 상대 인 최** 항소심에서 집행 유예없이 징역 선고와...
# 1536     백화점중간관리가봉인가요? 직원들 최저시급.퇴직금.세금..이러다 쪽박차게 생겼습니다.
# 1537                                    핑크택스 철폐를 청원합니다.
# 1538                                   다단계제품 인터넷재판매 금지법
# 1539     8월  13일 울산  7세   여아  아동학대의심  사망사고  철저히  조사해주세요
#
#                                                 URL    카테고리  \
# 0     https://www1.president.go.kr/petitions/590341   안전/환경
# 1     https://www1.president.go.kr/petitions/590416  인권/성평등
# 2     https://www1.president.go.kr/petitions/590504      행정
# 3     https://www1.president.go.kr/petitions/590550  인권/성평등
# 4     https://www1.president.go.kr/petitions/590879  인권/성평등
# ...                                             ...     ...
# 1535  https://www1.president.go.kr/petitions/586944      기타
# 1536  https://www1.president.go.kr/petitions/583127   경제민주화
# 1537  https://www1.president.go.kr/petitions/583516  인권/성평등
# 1538  https://www1.president.go.kr/petitions/580185      기타
# 1539  https://www1.president.go.kr/petitions/582090   육아/교육
#
#                                                    청원내용       청원시작일  \
# 0     2020년 6월 8일 월요일 오후 3시 15분오후 3시 15분경 어머님의 호흡이 너...  2020-07-03
# 1     현재 대법관 후보에 올라있는 강영수 판사는 현재 세계 최대의 아동 성착취물 사이트인...  2020-07-06
# 2     7월 8일, 중앙재난안전대책본부 "교회의 책임자와 이용자는 7월 10일(금) 18시...  2020-07-08
# 3     박원순씨가 사망하는 바람에 성추행 의혹은 수사도 하지 못한 채 종결되었지만그렇다고 ...  2020-07-10
# 4     6월 19일 첫 신고 시 학교측은 성폭력 매뉴얼대로 진행하지 않고 사건을 축소하여 ...  2020-07-16
# ...                                                 ...         ...
# 1535  앞으로 열리는 ****의 구** 씨의 원래 교제 상대 수 최** 항소심에서 집행 유...  2020-03-23
# 1536  백화점중간관리매니져입니다경기악화로 매출이 나날이 줄어가고있는실정에 있는직원들최저시급...  2019-10-16
# 1537  ‘핑크택스(Pink Tax)’에 대해 들어보신 적 있나요?핑크택스란 동일한 제품, ...  2019-11-11
# 1538  우리나라 네트워크 마케팅 판매업에 종사하는 분들은후원방문 판매와 비슷한 유통 방식으...  2019-05-14
# 1539  7살  여아  학대의심  사망사건입니다.아동학대  사건들에   철저한  수사와   ...  2019-08-16
#
#            청원종료일    참여인원
# 0     2020-08-02  735972
# 1     2020-08-05  529144
# 2     2020-08-07  427470
# 3     2020-08-09  596410
# 4     2020-08-15  252624
# ...          ...     ...
# 1535  2020-04-22   11205
# 1536  2019-11-15   11196
# 1537  2019-12-11   11181
# 1538  2019-06-13   11160
# 1539  2019-09-15   11151
#
# [1685 rows x 7 columns]

# %%
petition_best.sort_values(by='청원시작일', ascending = True)
# Out:
#                                                      제목      카테고리  \
# 1527                               기간제 교사의 정규직화를 반대합니다.     육아/교육
# 604              유아교육법 제 24조 2항에 명시된 '원칙'을 지켜주시기를 바랍니다.     육아/교육
# 223   남성만의 실질적 독박 국방의무 이행에서 벗어나 여성도 의무 이행에 동참하도록 법률개...  외교/통일/국방
# 600                                   여자 집값 70% 지원정책 폐지    인권/성평등
# 1341                    시골 남성들에 대한 매매혼 지원금 지급 중지를 바랍니다.    인권/성평등
# ...                                                 ...       ...
# 104                                전남 순천 슈퍼확진자 구상권 청구 외      보건복지
# 24                              공공의대 정책의 완전한 철회를 청원합니다.      보건복지
# 47        고속도로 음주사상사고 초동수사 미흡한 경찰과 파렴치한 가해자를 엄중 처벌해주세요.     안전/환경
# 50    塵人 조은산이 뉴노멀의 정신을 받들어 거천삼석의 상소문을 올리니 삼가 굽어 살펴주시옵소서      정치개혁
# 139                               범죄자 의사의 자격을 영구박탈해주세요!      보건복지
#
#                                                    청원내용       청원시작일  \
# 1527  대통령님, 안녕하세요. 저는 임용을 준비하고 수험생입니다. 처음 기간제 정규직화 된...  2017-08-19
# 604   안녕하십니까. 저는 '나라다운 나라'라는 캐치프레이즈(catch phrase)를 사...  2017-08-26
# 223   우리나라에선 아주 나중엔 모병으로 방향을 잡을지는 모르겠으나 지금 현 상황은 주적 ...  2017-08-30
# 600   현재 진행중인 1인가구 여성 임대주택 70%지원 정책 폐지를 요청합니다.국가가 나서...  2017-08-31
# 1341  시골 노총각들의 매매혼, 국제결혼이라는 이름으로 좋게 포장되지만 실상은 인신매매와 ...  2017-09-02
# ...                                                 ...         ...
# 104   안녕하세요.존경하는 문재인 대통령님 이하 현재 이 코로나 각자 포지션에서 최선을 다...  2020-08-27
# 24    안녕하신지요. 현재 서울의 한 대학에 재학 중인 학생입니다. 본격적인 청원에 앞서현...  2020-08-28
# 47    지난 6월 22일 새벽 1시 40분경 시골로 향하시던 부모님 차량을 음주운전 차량이...  2020-08-28
# 50    塵人 조은산이 뉴노멀의 정신을 받들어 거천삼석의 상소문을올리니 삼가 굽어 살펴주시옵...  2020-08-28
# 139   몇해전 가수***의 의료사고로 인한 사망사고가 발생했습니다. 또한 같은 의료사고를 ...  2020-08-28
#
#            청원종료일    참여인원
# 1527  2017-09-18   11293
# 604   2017-09-02   34318
# 223   2017-09-14  123204
# 600   2017-11-29   34750
# 1341  2017-10-02   13370
# ...          ...     ...
# 104   2020-09-26   15154
# 24    2020-09-27   75546
# 47    2020-09-27   41286
# 50    2020-09-27   38585
# 139   2020-09-27    9701
#
# [1685 rows x 6 columns]

# %%
petition_best[petition_best['청원내용'] == '']
# Out:
# Empty DataFrame
# Columns: [제목, URL, 카테고리, 청원내용, 청원시작일, 청원종료일, 참여인원]
# Index: []

# %%
petition_best = petition_best.drop('URL', axis=1)
petition_best
# Out:
#                                                      제목    카테고리  \
# 0                    응급환자가 있는 구급차를 막아세운 택시 기사를 처벌해 주세요.   안전/환경
# 1                 강영수 서울고법 수석부장판사의 대법관 후보 자격 박탈을 청원합니다.  인권/성평등
# 2                        정부의 교회 정규 예배 이외 행사 금지를 취소해주세요.      행정
# 3                 박원순씨 장례를 5일장, 서울특별시장(葬)으로 하는 것 반대합니다.  인권/성평등
# 4        학교내성폭력 및 학교.상급기관의 미흡한 대처로 아픔을 호소하다 하늘나라에 갔습니다.  인권/성평등
# ...                                                 ...     ...
# 1535  **의 구** 씨의 원래 교제 상대 인 최** 항소심에서 집행 유예없이 징역 선고와...      기타
# 1536     백화점중간관리가봉인가요? 직원들 최저시급.퇴직금.세금..이러다 쪽박차게 생겼습니다.   경제민주화
# 1537                                    핑크택스 철폐를 청원합니다.  인권/성평등
# 1538                                   다단계제품 인터넷재판매 금지법      기타
# 1539     8월  13일 울산  7세   여아  아동학대의심  사망사고  철저히  조사해주세요   육아/교육
#
#                                                    청원내용       청원시작일  \
# 0     2020년 6월 8일 월요일 오후 3시 15분오후 3시 15분경 어머님의 호흡이 너...  2020-07-03
# 1     현재 대법관 후보에 올라있는 강영수 판사는 현재 세계 최대의 아동 성착취물 사이트인...  2020-07-06
# 2     7월 8일, 중앙재난안전대책본부 "교회의 책임자와 이용자는 7월 10일(금) 18시...  2020-07-08
# 3     박원순씨가 사망하는 바람에 성추행 의혹은 수사도 하지 못한 채 종결되었지만그렇다고 ...  2020-07-10
# 4     6월 19일 첫 신고 시 학교측은 성폭력 매뉴얼대로 진행하지 않고 사건을 축소하여 ...  2020-07-16
# ...                                                 ...         ...
# 1535  앞으로 열리는 ****의 구** 씨의 원래 교제 상대 수 최** 항소심에서 집행 유...  2020-03-23
# 1536  백화점중간관리매니져입니다경기악화로 매출이 나날이 줄어가고있는실정에 있는직원들최저시급...  2019-10-16
# 1537  ‘핑크택스(Pink Tax)’에 대해 들어보신 적 있나요?핑크택스란 동일한 제품, ...  2019-11-11
# 1538  우리나라 네트워크 마케팅 판매업에 종사하는 분들은후원방문 판매와 비슷한 유통 방식으...  2019-05-14
# 1539  7살  여아  학대의심  사망사건입니다.아동학대  사건들에   철저한  수사와   ...  2019-08-16
#
#            청원종료일    참여인원
# 0     2020-08-02  735972
# 1     2020-08-05  529144
# 2     2020-08-07  427470
# 3     2020-08-09  596410
# 4     2020-08-15  252624
# ...          ...     ...
# 1535  2020-04-22   11205
# 1536  2019-11-15   11196
# 1537  2019-12-11   11181
# 1538  2019-06-13   11160
# 1539  2019-09-15   11151
#
# [1685 rows x 6 columns]

# %%
petition_best.sort_values(by='청원시작일')
# Out:
#                                                      제목      카테고리  \
# 1527                               기간제 교사의 정규직화를 반대합니다.     육아/교육
# 604              유아교육법 제 24조 2항에 명시된 '원칙'을 지켜주시기를 바랍니다.     육아/교육
# 223   남성만의 실질적 독박 국방의무 이행에서 벗어나 여성도 의무 이행에 동참하도록 법률개...  외교/통일/국방
# 600                                   여자 집값 70% 지원정책 폐지    인권/성평등
# 1341                    시골 남성들에 대한 매매혼 지원금 지급 중지를 바랍니다.    인권/성평등
# ...                                                 ...       ...
# 104                                전남 순천 슈퍼확진자 구상권 청구 외      보건복지
# 24                              공공의대 정책의 완전한 철회를 청원합니다.      보건복지
# 47        고속도로 음주사상사고 초동수사 미흡한 경찰과 파렴치한 가해자를 엄중 처벌해주세요.     안전/환경
# 50    塵人 조은산이 뉴노멀의 정신을 받들어 거천삼석의 상소문을 올리니 삼가 굽어 살펴주시옵소서      정치개혁
# 139                               범죄자 의사의 자격을 영구박탈해주세요!      보건복지
#
#                                                    청원내용       청원시작일  \
# 1527  대통령님, 안녕하세요. 저는 임용을 준비하고 수험생입니다. 처음 기간제 정규직화 된...  2017-08-19
# 604   안녕하십니까. 저는 '나라다운 나라'라는 캐치프레이즈(catch phrase)를 사...  2017-08-26
# 223   우리나라에선 아주 나중엔 모병으로 방향을 잡을지는 모르겠으나 지금 현 상황은 주적 ...  2017-08-30
# 600   현재 진행중인 1인가구 여성 임대주택 70%지원 정책 폐지를 요청합니다.국가가 나서...  2017-08-31
# 1341  시골 노총각들의 매매혼, 국제결혼이라는 이름으로 좋게 포장되지만 실상은 인신매매와 ...  2017-09-02
# ...                                                 ...         ...
# 104   안녕하세요.존경하는 문재인 대통령님 이하 현재 이 코로나 각자 포지션에서 최선을 다...  2020-08-27
# 24    안녕하신지요. 현재 서울의 한 대학에 재학 중인 학생입니다. 본격적인 청원에 앞서현...  2020-08-28
# 47    지난 6월 22일 새벽 1시 40분경 시골로 향하시던 부모님 차량을 음주운전 차량이...  2020-08-28
# 50    塵人 조은산이 뉴노멀의 정신을 받들어 거천삼석의 상소문을올리니 삼가 굽어 살펴주시옵...  2020-08-28
# 139   몇해전 가수***의 의료사고로 인한 사망사고가 발생했습니다. 또한 같은 의료사고를 ...  2020-08-28
#
#            청원종료일    참여인원
# 1527  2017-09-18   11293
# 604   2017-09-02   34318
# 223   2017-09-14  123204
# 600   2017-11-29   34750
# 1341  2017-10-02   13370
# ...          ...     ...
# 104   2020-09-26   15154
# 24    2020-09-27   75546
# 47    2020-09-27   41286
# 50    2020-09-27   38585
# 139   2020-09-27    9701
#
# [1685 rows x 6 columns]

# %%
petition_best.to_csv('Final-Blue-House-Petition-data-Best.csv', sep=',', encoding='utf-8')

# %% [markdown]
# ### EDA, 워드클라우드 작업

# %%
import pandas as pd
import platform
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import platform 
from matplotlib import font_manager, rc 
plt.rcParams['axes.unicode_minus'] = False
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system')

# %%
petition = pd.read_csv('Final-Blue-House-Petition-data-Best.csv', thousands=',', encoding='utf-8', index_col=0)
petition.head()
# Out:
#                                                 제목    카테고리  \
# 0               응급환자가 있는 구급차를 막아세운 택시 기사를 처벌해 주세요.   안전/환경
# 1            강영수 서울고법 수석부장판사의 대법관 후보 자격 박탈을 청원합니다.  인권/성평등
# 2                   정부의 교회 정규 예배 이외 행사 금지를 취소해주세요.      행정
# 3            박원순씨 장례를 5일장, 서울특별시장(葬)으로 하는 것 반대합니다.  인권/성평등
# 4   학교내성폭력 및 학교.상급기관의 미흡한 대처로 아픔을 호소하다 하늘나라에 갔습니다.  인권/성평등
#
#                                                 청원내용       청원시작일       청원종료일  \
# 0  2020년 6월 8일 월요일 오후 3시 15분오후 3시 15분경 어머님의 호흡이 너...  2020-07-03  2020-08-02
# 1  현재 대법관 후보에 올라있는 강영수 판사는 현재 세계 최대의 아동 성착취물 사이트인...  2020-07-06  2020-08-05
# 2  7월 8일, 중앙재난안전대책본부 "교회의 책임자와 이용자는 7월 10일(금) 18시...  2020-07-08  2020-08-07
# 3  박원순씨가 사망하는 바람에 성추행 의혹은 수사도 하지 못한 채 종결되었지만그렇다고 ...  2020-07-10  2020-08-09
# 4  6월 19일 첫 신고 시 학교측은 성폭력 매뉴얼대로 진행하지 않고 사건을 축소하여 ...  2020-07-16  2020-08-15
#
#      참여인원
# 0  735972
# 1  529144
# 2  427470
# 3  596410
# 4  252624

# %%
petition_ctgry = petition['카테고리'].value_counts()
petition_ctgry.sort_values().plot(kind='barh', grid=True, figsize=(10,10))
plt.title('카테고리 별 청원목록 개수 2017.8 ~ 2020.8')
plt.show()

# %%
petition['청원시작일'] = petition['청원시작일'].astype('datetime64[ns]')

# %%
seven = petition['청원시작일'].dt.year == 2017
petition_17 = petition[seven]
 
eight = petition['청원시작일'].dt.year == 2018
petition_18 = petition[eight]

nine = petition['청원시작일'].dt.year == 2019
petition_19 = petition[nine]

ten = petition['청원시작일'].dt.year == 2020
petition_20 = petition[ten]

# %%
petition_18
# Out:
#                                                      제목         카테고리  \
# 6                         강서구 피시방 살인 사건. 또 심신미약 피의자입니다.        안전/환경
# 12    제주도 불법 난민 신청 문제에 따른 난민법, 무사증 입국, 난민신청허가 폐지/개헌 ...     외교/통일/국방
# 15             김보름, 박지우 선수의 자격박탈과 적폐 빙상연맹의 엄중 처벌을 청원합니다  문화/예술/체육/언론
# 27               여성도 대한민국 국민입니다. 성별 관계없는 국가의 보호를 요청합니다.       인권/성평등
# 28    132cm, 31kg의 왜소한 50대 여성이 180cm가 넘는 건장한 20세 남성에...       인권/성평등
# ...                                                 ...          ...
# 1514         동탄2신도시 지상 환승정류장 폐기및 경부고속도로 지하화 공사 즉각 재개 요청     교통/건축/국토
# 1525                 불법촬영물과 웹하드 이 거대한 조직을 강력 처벌해야만 합니다.       인권/성평등
# 1529                             공인중개사 시험 재시험 당장 검토해주세요          일자리
# 1530             동성애 옹호자 최영애 국가인권위원장 내정자의 지명을 철회해 주세요!!       인권/성평등
# 1532               공공시설(인천-아시아드 주경기장)신천지의 위장행사장 대관취소 요청  문화/예술/체육/언론
#
#                                                    청원내용      청원시작일  \
# 6     2018년 10월 14일 엊그제 일어난 강서구 피시방 살인사건에 대한 청원입니다. ... 2018-10-17
# 12    2012년 난민법 제정으로 인해 외국인은 한달 무비자로 입국할 수 있으나 난민신청자... 2018-06-13
# 15    오늘 여자 단체전 팀추월에서 김보름, 박지우 선수는 팀전인데도 불구하고 개인의 영달... 2018-02-19
# 27                                                  NaN 2018-05-11
# 28    http://m.news1.kr/articles/?3464603관련 기사입니다.20... 2018-10-31
# ...                                                 ...        ...
# 1514  제목 : 동탄2신도시 지상 환승정류장 폐기및 경부고속도로 지하화 공사 즉각 재개 요... 2018-06-04
# 1525  정부가 불법촬영물 영상물 삭제 등을 지원하는 ‘디지털 성범죄 피해자 지원센터’를 설... 2018-07-29
# 1529  난이도를 올려도 수긍이 갈만큼 해야지이건 난이도 문제가 아니라 그냥 불합격시키려고 ... 2018-10-27
# 1530  동성애 옹호자 최영애 국가인권위원장 내정자의 지명을 철회해 주세요!!1. 최영애 내... 2018-08-11
# 1532  사이비 신천지가 인천 아시아드 경기장(9월 17~18일)에서 평화행사를 빙자한  교... 2018-09-10
#
#            청원종료일     참여인원
# 6     2018-11-16  1192049
# 12    2018-07-13   714875
# 15    2018-03-21   614127
# 27    2018-06-10   419006
# 28    2018-11-30   416093
# ...          ...      ...
# 1514  2018-07-04    11395
# 1525  2018-08-28    11309
# 1529  2018-11-26    11265
# 1530  2018-09-10    11256
# 1532  2018-10-10    11218
#
# [513 rows x 6 columns]

# %% [markdown]
# ### 2017~2020년 카테고리 별 청원목록 개수

# %%
petition_ctgry_17 = petition_17['카테고리'].value_counts()
petition_ctgry_17.sort_values().plot(kind='barh', grid=True, figsize=(10,10))
plt.title('카테고리 별 청원목록 개수 2017년')
plt.show()

# %%
petition_ctgry_18 = petition_18['카테고리'].value_counts()
petition_ctgry_18.sort_values().plot(kind='barh', grid=True, figsize=(10,10))
plt.title('카테고리 별 청원목록 개수 2018년')
plt.show()

# %%
petition_ctgry_19 = petition_19['카테고리'].value_counts()
petition_ctgry_19.sort_values().plot(kind='barh', grid=True, figsize=(10,10))
plt.title('카테고리 별 청원목록 개수 2019년')
plt.show()

# %%
petition_ctgry_20 = petition_20['카테고리'].value_counts()
petition_ctgry_20.sort_values().plot(kind='barh', grid=True, figsize=(10,10))
plt.title('카테고리 별 청원목록 개수 2020년')
plt.show()

# %% [markdown]
# ### 인권/성평등 카테고리 분석

# %%
petition_gender = petition[petition['카테고리'] == '인권/성평등']
petition_gender.sort_values(by='청원시작일')
# Out:
#                                                      제목    카테고리  \
# 600                                   여자 집값 70% 지원정책 폐지  인권/성평등
# 1341                    시골 남성들에 대한 매매혼 지원금 지급 중지를 바랍니다.  인권/성평등
# 218   청소년이란 이유로 보호법을 악용하는 잔인무도한 청소년들이 늘어나고있습니다. 반드시 ...  인권/성평등
# 62    청소년이란 이유로 보호법을 악용하는 잔인무도한 청소년들이 늘어나고있습니다. 반드시 ...  인권/성평등
# 887                      출생시 아이가 기본적으로 어머니의 성을 따르게 해주세요  인권/성평등
# ...                                                 ...     ...
# 130                                     춘천 의암댐 선박 점복 사고  인권/성평등
# 20                                 *** 웹툰 연재 중지를 요구합니다.  인권/성평등
# 46                전남담양폭우  희생된 8살아이에 ***이라는 일베유저 엄벌요구합니다  인권/성평등
# 111                          ***법 (무고죄 강력처벌법) 을 만들어주세요.  인권/성평등
# 83                               백화점 판매사원들을 코로나에서 구해주세요  인권/성평등
#
#                                                    청원내용      청원시작일  \
# 600   현재 진행중인 1인가구 여성 임대주택 70%지원 정책 폐지를 요청합니다.국가가 나서... 2017-08-31
# 1341  시골 노총각들의 매매혼, 국제결혼이라는 이름으로 좋게 포장되지만 실상은 인신매매와 ... 2017-09-02
# 218   안녕하십니까. [소년법]이란 명목하에 나쁜짓을 일삼는 청소년들이 너무나 많아지고 있... 2017-09-03
# 62    안녕하십니까. 청소년보호법이란 명목하에 나쁜짓을 일삼는 청소년들이 너무나 많아지고 ... 2017-09-03
# 887   모든 것을 관습적으로 따르던 시대를 벗어나고 있습니다.의무와 그에 따른 권리를 논리... 2017-09-05
# ...                                                 ...        ...
# 130   안녕하세요.저는 이번에 춘천 의암대 선박 점복 사고자의딸 입니다. 어제 일하다가 갑... 2020-08-11
# 20    안녕하세요. 평소에 *** 웹툰을 즐겨보고 관심있게 보는 학생입니다.이번에 올라온 ... 2020-08-12
# 46    요몇일 폭우로 전라도뿐 아니라  전국이 많이힘든 상황입니다.  그리고 재난이  쓸고... 2020-08-13
# 111   최근 미투운동이 전개되면서 억울하고 힘없는 여성분들의 고통을 분담하는 좋은 영향이 ... 2020-08-19
# 83    사회적거리두기2단계격상,재택근무하기, 단축근무, 휴관 이모두가,코로나로인한 심각한 ... 2020-08-25
#
#            청원종료일    참여인원
# 600   2017-11-29   34750
# 1341  2017-10-02   13370
# 218   2017-11-02  125343
# 62    2017-11-02  296330
# 887   2017-12-04   22392
# ...          ...     ...
# 130   2020-09-10   11358
# 20    2020-09-11  125323
# 46    2020-09-12   41660
# 111   2020-09-18   12546
# 83    2020-09-24   18806
#
# [312 rows x 6 columns]

# %%
petition_gender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 312 entries, 1 to 1537
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제목      312 non-null    object
#  1   카테고리    312 non-null    object
#  2   청원내용    310 non-null    object
#  3   청원시작일   312 non-null    datetime64[ns]
#  4   청원종료일   312 non-null    object
#  5   참여인원    312 non-null    int64
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 17.1+ KB

# %%
seven = petition_gender['청원시작일'].dt.year == 2017
pg_17 = petition_gender[seven]
 
eight = petition_gender['청원시작일'].dt.year == 2018
pg_18 = petition_gender[eight]

nine = petition_gender['청원시작일'].dt.year == 2019
pg_19 = petition_gender[nine]

ten = petition_gender['청원시작일'].dt.year == 2020
pg_20 = petition_gender[ten]

# %%
print(len(pg_17))
print(len(pg_18))
print(len(pg_19))
print(len(pg_20))
# Out:
# 16
# 113
# 77
# 106

# %%
plt.plot(['2017','2018','2019','2020'], [16, 113, 77, 106])
plt.rcParams['figure.figsize'] = [20, 20]
plt.xlabel('년도')
plt.ylabel('인권/성평등 청원개수')
plt.show()

# %% [markdown]
# ### 워드클라우드 시각화

# %%
import nltk
from konlpy.tag import Okt
okt = Okt()

# %%
petition_gender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 312 entries, 1 to 1537
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제목      312 non-null    object
#  1   카테고리    312 non-null    object
#  2   청원내용    310 non-null    object
#  3   청원시작일   312 non-null    datetime64[ns]
#  4   청원종료일   312 non-null    object
#  5   참여인원    312 non-null    int64
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 17.1+ KB

# %%
petition_gender.shape
# Out:
# (312, 6)

# %%
petition_gender['청원내용'] = petition_gender['청원내용'].apply(str)
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
petition_gender_text = ''

for each_line in petition_gender['청원내용']: 
    petition_gender_text = petition_gender_text + each_line + '\n'

# %%
tokens_ko = okt.morphs(petition_gender_text)

# %%
stop_words = ['.','을','이','의','를','에',',','가','들','은','는','으로','한','도',
              '수','에서','로','것','그','과','제','입니다','할','하고','적',"'",'하는',
              '합니다','와','에게','고','인',')','?','하여','등','저','있습니다','말','까지',
              '(','1','그리고','다','2','만','딸','했습니다','안','된','못','일','더','위',
              '있는','해','\n','또한','명','하지','..','정말','물','많은','"',
              '중','3','게','너무','A','자','이런','때','되지','위해','에는','없는',
              '및','요','때문','관련','대한','전','라고','되었습니다','하기','나','후','같은','해서',
              '글','되어','주','차','하','내','없이','대해','잘','하지만','결국', '\'', '`', '하였습니다',
             ':', '대한민국', '라는', '‘', '’', '”', '“', '님', '씨', '에도', '하게', '알', '-',
             '또', '해야', '지', '분', '에서는', '않고', '아닌', '아니라', '하면', '하였고']

tokens_ko = [each_word for each_word in tokens_ko if each_word not in stop_words]

ko = nltk.Text(tokens_ko, name='인권/성평등 청원내용')
ko.vocab().most_common(50)
# Out:
# [('피해자', 968),
#  ('여성', 786),
#  ('사건', 766),
#  ('가해자', 744),
#  ('성', 565),
#  ('사람', 534),
#  ('경찰', 458),
#  ('국민', 452),
#  ('처벌', 440),
#  ('생각', 438),
#  ('아이', 387),
#  ('수사', 337),
#  ('청원', 334),
#  ('저희', 297),
#  ('범죄', 296),
#  ('남성', 296),
#  ('법', 283),
#  ('사회', 276),
#  ('사실', 272),
#  ('진술', 271),
#  ('증거', 271),
#  ('성폭행', 256),
#  ('피해', 248),
#  ('우리', 248),
#  ('자신', 245),
#  ('내용', 240),
#  ('친구', 236),
#  ('여', 236),
#  ('학교', 235),
#  ('성범죄', 232),
#  ('하며', 231),
#  ('이유', 225),
#  ('현재', 219),
#  ('학생', 209),
#  ('인권', 208),
#  ('서', 207),
#  ('보호', 205),
#  ('신고', 202),
#  ('조사', 195),
#  ('가족', 186),
#  ('여자', 185),
#  ('모든', 184),
#  ('성매매', 184),
#  ('**', 183),
#  ('다른', 183),
#  ('이상', 174),
#  ('경우', 172),
#  ('검사', 172),
#  ('지금', 169),
#  ('국가', 164)]

# %%
plt.figure(figsize=(15,6))
ko.plot(50)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
data = dict(ko.vocab().most_common(150))

# %%
wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',
                      relative_scaling = 0.2,
                      background_color='white',).generate_from_frequencies(data)
plt.figure(figsize=(12,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.title('인권/성평등 청원내용')
plt.show()

# %%
pg_text = ''

for each_line in pg_17['청원내용']: 
    pg_text = pg_text + each_line + '\n'

# %%
tokens_ko = okt.morphs(pg_text)

# %%
stop_words = ['.','을','이','의','를','에',',','가','들','은','는','으로','한','도',
              '수','에서','로','것','그','과','제','입니다','할','하고','적',"'",'하는',
              '합니다','와','에게','고','인',')','?','하여','등','저','있습니다','말','까지',
              '(','1','그리고','다','2','만','딸','했습니다','안','된','못','일','더','위',
              '있는','해','\n','또한','명','하지','..','정말','물','많은','"',
              '중','3','게','너무','A','자','이런','때','되지','위해','에는','없는',
              '및','요','때문','관련','대한','전','라고','되었습니다','하기','나','후','같은','해서',
              '글','되어','주','차','하','내','없이','대해','잘','하지만','결국', '\'', '`', '하였습니다',
             ':', '대한민국', '라는', '‘', '’', '”', '“', '님', '씨', '에도', '하게', '알', '-',
             '또', '해야', '지', '분', '에서는', '않고', '아닌', '아니라', '하면', '하였고','...', '아닙니다',
             '없고', '없습니다', '이라는', '한다고']

tokens_ko = [each_word for each_word in tokens_ko if each_word not in stop_words]

ko = nltk.Text(tokens_ko, name='인권/성평등 청원내용')
ko.vocab().most_common(50)
# Out:
# [('생각', 38),
#  ('사건', 36),
#  ('여성', 36),
#  ('피해자', 32),
#  ('청소년', 29),
#  ('경찰관', 27),
#  ('경찰', 27),
#  ('아이', 23),
#  ('국가', 22),
#  ('순직', 21),
#  ('우리', 20),
#  ('가해자', 20),
#  ('사회', 20),
#  ('이유', 19),
#  ('사람', 19),
#  ('국민', 19),
#  ('준영', 19),
#  ('처벌', 17),
#  ('아들', 17),
#  ('현장', 17),
#  ('남성', 17),
#  ('보호', 16),
#  ('성인', 15),
#  ('원', 15),
#  ('나라', 15),
#  ('사망', 15),
#  ('법', 14),
#  ('청원', 14),
#  ('낙태', 14),
#  ('범죄', 13),
#  ('하며', 13),
#  ('현재', 12),
#  ('성', 12),
#  ('신고', 12),
#  ('성범죄', 12),
#  ('무고죄', 12),
#  ('경우', 11),
#  ('모두', 11),
#  ('않는', 11),
#  ('근무', 11),
#  ('인간', 10),
#  ('모든', 10),
#  ('폐지', 10),
#  ('임신', 10),
#  ('상황', 10),
#  ('인권', 10),
#  ('기사', 10),
#  ('폭행', 9),
#  ('자신', 9),
#  ('이나', 9)]

# %%
data = dict(ko.vocab().most_common(150))
wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',
                      relative_scaling = 0.2,
                      background_color='white',).generate_from_frequencies(data)
plt.figure(figsize=(12,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.title('2017년 인권/성평등 청원내용')
plt.show()

# %%
pg_text = ''

for each_line in pg_18['청원내용']: 
    pg_text = pg_text + each_line + '\n'

# %%
tokens_ko_18 = okt.morphs(pg_text)

# %%
stop_words = ['.','을','이','의','를','에',',','가','들','은','는','으로','한','도',
              '수','에서','로','것','그','과','제','입니다','할','하고','적',"'",'하는',
              '합니다','와','에게','고','인',')','?','하여','등','저','있습니다','말','까지',
              '(','1','그리고','다','2','만','딸','했습니다','안','된','못','일','더','위',
              '있는','해','\n','또한','명','하지','..','정말','물','많은','"',
              '중','3','게','너무','A','자','이런','때','되지','위해','에는','없는',
              '및','요','때문','관련','대한','전','라고','되었습니다','하기','나','후','같은','해서',
              '글','되어','주','차','하','내','없이','대해','잘','하지만','결국', '\'', '`', '하였습니다',
             ':', '대한민국', '라는', '‘', '’', '”', '“', '님', '씨', '에도', '하게', '알', '-',
             '또', '해야', '지', '분', '에서는', '않고', '아닌', '아니라', '하면', '하였고','...', '아닙니다',
             '없고', '없습니다', '이라는', '한다고', '서', '하며','부터']

tokens_ko_18 = [each_word for each_word in tokens_ko if each_word not in stop_words]

ko = nltk.Text(tokens_ko_18, name='인권/성평등 청원내용')
ko.vocab().most_common(50)
# Out:
# [('피해자', 968),
#  ('여성', 786),
#  ('사건', 766),
#  ('가해자', 744),
#  ('성', 565),
#  ('사람', 534),
#  ('경찰', 458),
#  ('국민', 452),
#  ('처벌', 440),
#  ('생각', 438),
#  ('아이', 387),
#  ('수사', 337),
#  ('청원', 334),
#  ('저희', 297),
#  ('범죄', 296),
#  ('남성', 296),
#  ('법', 283),
#  ('사회', 276),
#  ('사실', 272),
#  ('진술', 271),
#  ('증거', 271),
#  ('성폭행', 256),
#  ('피해', 248),
#  ('우리', 248),
#  ('자신', 245),
#  ('내용', 240),
#  ('친구', 236),
#  ('여', 236),
#  ('학교', 235),
#  ('성범죄', 232),
#  ('이유', 225),
#  ('현재', 219),
#  ('학생', 209),
#  ('인권', 208),
#  ('보호', 205),
#  ('신고', 202),
#  ('조사', 195),
#  ('가족', 186),
#  ('여자', 185),
#  ('모든', 184),
#  ('성매매', 184),
#  ('**', 183),
#  ('다른', 183),
#  ('이상', 174),
#  ('경우', 172),
#  ('검사', 172),
#  ('지금', 169),
#  ('국가', 164),
#  ('성폭력', 159),
#  ('행위', 159)]

# %%
data = dict(ko.vocab().most_common(150))
wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',
                      relative_scaling = 0.2,
                      background_color='white',).generate_from_frequencies(data)
plt.figure(figsize=(12,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.title('2018년 인권/성평등 청원내용')
plt.show()

# %%
pg_text = ''

for each_line in pg_19['청원내용']: 
    pg_text = pg_text + each_line + '\n'

tokens_ko_19 = okt.morphs(pg_text)
stop_words = ['.','을','이','의','를','에',',','가','들','은','는','으로','한','도',
              '수','에서','로','것','그','과','제','입니다','할','하고','적',"'",'하는',
              '합니다','와','에게','고','인',')','?','하여','등','저','있습니다','말','까지',
              '(','1','그리고','다','2','만','딸','했습니다','안','된','못','일','더','위',
              '있는','해','\n','또한','명','하지','..','정말','물','많은','"',
              '중','3','게','너무','A','자','이런','때','되지','위해','에는','없는',
              '및','요','때문','관련','대한','전','라고','되었습니다','하기','나','후','같은','해서',
              '글','되어','주','차','하','내','없이','대해','잘','하지만','결국', '\'', '`', '하였습니다',
             ':', '대한민국', '라는', '‘', '’', '”', '“', '님', '씨', '에도', '하게', '알', '-',
             '또', '해야', '지', '분', '에서는', '않고', '아닌', '아니라', '하면', '하였고','...', '아닙니다',
             '없고', '없습니다', '이라는', '한다고', '서', '하며','부터', '사실', '했고']

tokens_ko_19 = [each_word for each_word in tokens_ko_19 if each_word not in stop_words]

ko = nltk.Text(tokens_ko_19, name='인권/성평등 청원내용')
ko.vocab().most_common(50)

data = dict(ko.vocab().most_common(150))
wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',
                      relative_scaling = 0.2,
                      background_color='white',).generate_from_frequencies(data)
plt.figure(figsize=(12,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.title('2019년 인권/성평등 청원내용')
plt.show()

# %%
pg_text = ''

for each_line in pg_20['청원내용']: 
    pg_text = pg_text + each_line + '\n'

tokens_ko_20 = okt.morphs(pg_text)
stop_words = ['.','을','이','의','를','에',',','가','들','은','는','으로','한','도',
              '수','에서','로','것','그','과','제','입니다','할','하고','적',"'",'하는',
              '합니다','와','에게','고','인',')','?','하여','등','저','있습니다','말','까지',
              '(','1','그리고','다','2','만','딸','했습니다','안','된','못','일','더','위',
              '있는','해','\n','또한','명','하지','..','정말','물','많은','"',
              '중','3','게','너무','A','자','이런','때','되지','위해','에는','없는',
              '및','요','때문','관련','대한','전','라고','되었습니다','하기','나','후','같은','해서',
              '글','되어','주','차','하','내','없이','대해','잘','하지만','결국', '\'', '`', '하였습니다',
             ':', '대한민국', '라는', '‘', '’', '”', '“', '님', '씨', '에도', '하게', '알', '-',
             '또', '해야', '지', '분', '에서는', '않고', '아닌', '아니라', '하면', '하였고','...', '아닙니다',
             '없고', '없습니다', '이라는', '한다고', '서', '하며','부터', '사실', '했고','이라고','니까',
             '일이']

tokens_ko_20 = [each_word for each_word in tokens_ko_20 if each_word not in stop_words]

ko = nltk.Text(tokens_ko_20, name='인권/성평등 청원내용')
ko.vocab().most_common(50)

data = dict(ko.vocab().most_common(150))
wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',
                      relative_scaling = 0.2,
                      background_color='white',).generate_from_frequencies(data)
plt.figure(figsize=(12,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.title('2020년 인권/성평등 청원내용')
plt.show()
